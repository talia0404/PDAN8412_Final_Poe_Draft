# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/gauravkamath02/precious-gemstone-identification
#
# Connecting my dataset to colab for analysis:

# %% [markdown]
# Set permissions so the owner of the file has read and write permissions.

# %%
import os

# !chmod 600 /root/.kaggle/kaggle.json

# %% [markdown]
# Verify that Kaggle is set up correctly:

# %%
# !kaggle datasets list
# Out:
# ref                                                          title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# muhammadroshaanriaz/students-performance-dataset-cleaned     Students Performance | Clean Dataset                10KB  2024-10-29 19:32:26           4693         86  1.0
# ironwolf437/laptop-price-dataset                             Laptop Price - dataset‏                             25KB  2024-11-12 15:50:44            991         27  1.0
# valakhorasani/mobile-device-usage-and-user-behavior-dataset  Mobile Device Usage and User Behavior Dataset       11KB  2024-09-28 20:21:12          25830        512  1.0
# ...

# %% [markdown]
# Downloading the dataset.

# %%
# !kaggle datasets download -d gauravkamath02/precious-gemstone-identification
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gauravkamath02/precious-gemstone-identification
# License(s): MIT
# precious-gemstone-identification.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# Unzip the downloaded file:

# %%
import zipfile
with zipfile.ZipFile("precious-gemstone-identification.zip", 'r') as zip_ref:
    zip_ref.extractall("dataset")

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Define Paths

# %%
train_dir = "/content/dataset/GemStones/GemStones/GemStonesTensorflow/train"
val_dir = "/content/dataset/GemStones/GemStonesTensorflow/valid"
test_dir = "/content/dataset/GemStones/GemStones/GemStonesTensorflow/test"

# %% [markdown]
# Set Up ImageDataGenerator for Data Loading and Augmentation

# %%
# Define training data generator with augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    horizontal_flip=True,
    rotation_range=15,
    shear_range=0.1,
    brightness_range=[0.9, 1.1]
)

# %%
# Validation data generator (no augmentation)
val_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
# Load images in batches from directory
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(640, 640),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 0 images belonging to 0 classes.

# %%
# !ls -R dataset/GemStones
# Out:
# Streaming output truncated to the last 5000 lines.
# variscite_32_jpg.rf.fd6b61565e5d3ba9a7e8147f0383bd0d.txt
# variscite_32_jpg.rf.ff9aa6cf8f5a38a537f917f51ec4fcaa.txt
# variscite_33_jpg.rf.40642d4236642ad01a94681c2ea48088.txt
# variscite_33_jpg.rf.416d4e5ba7ed990f5a26e7c5708088c2.txt
# variscite_33_jpg.rf.4481dd96db1f1a7477d3900585e7f5de.txt
# variscite_33_jpg.rf.5b77141cc4222ab4cf594b5f8afb65b1.txt
# variscite_33_jpg.rf.7aea0bdd0a23c4668e6152787d89cd42.txt
# variscite_33_jpg.rf.8eaae845e0e9765cfaeda1c2681d7895.txt
# variscite_33_jpg.rf.9f49cd5c0a591f3ba36490a29038b614.txt
# variscite_33_jpg.rf.a5eb19a5658510973781c7436ebd5af3.txt
# variscite_33_jpg.rf.a7f2f01c111cafa0ce48d688394058b5.txt
# variscite_33_jpg.rf.a8b9008f09d33e5e5f7a0d0cc7f0cdaf.txt
# variscite_33_jpg.rf.acb8679fa6c6d444de2700072b65a637.txt
# variscite_33_jpg.rf.adccd152ce884c03cd2d9a1b09d054ac.txt
# variscite_33_jpg.rf.b4e0e459a3dce48474a53db24ec9d330.txt
# variscite_33_jpg.rf.c0dbd5767df5f76a5da24bc144d55dda.txt
# ...

# %%
val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(640, 640),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-db5e6f326cd2> in <cell line: 1>()
# ----> 1 val_generator = val_datagen.flow_from_directory(
#       2     val_dir,
#       3     target_size=(640, 640),
#       4     batch_size=32,
#       5     class_mode='categorical'
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...
